# %%
# %sql
LIST '/Volumes/spotify_dev/00_landing/spotify_extended_streaming_history'

# %%
# %sh
unzip /Volumes/spotify_dev/00_landing/spotify_extended_streaming_history/my_spotify_data.zip

# %%
# %sql
DESCRIBE VOLUME spotify_dev.00_landing.spotify_streaming_history_data
